# %%
"""
Created on Oct 13, 2020. 10.30pm
Data Science: Python - DAT-5301 - MsBA3 Year 2020
@author: Sian Yang Tan 
"""
"""
DocString:
    A) Introduction:
    
    This text adventure game was inspired by a horror thriller television series name 'Walking Dead'. 
    
    Imagined after the late night party in a Hult Alumni Event, you realised that you were drunk. 
    
    You awaken the next morning in a park near Levi's plaza. With head spinning and fighting the urge 
    
    to puke, you struggling to stand up and wondering what had happened last night. The puzzling feeling 
    
    fades when you hear a snarling sound emitting behind you. You are going through 4 scenarios to make 
    
    a few decision in going through a journey to strike for survival!!!
    
    There is no skill involved but some common sense and luck!!!!!
    
                                Introduction   : Get to know you better
                                Scenario_1_park: Starting point
                                Scenario_2_hult: Run into Hult campus for help
                                Scenario_3_pier: Run towards Pier direction
                                Out_of_the_pier: Outside the pier
    
    B) Known Bugs and/or Errors:
    None
"""

import time # import time module to add a pause
from sys import exit #import exit from sys to exit the game 

#Anticipating all possible responds from users
possible_answer_A_Q1 = {"a","run towards hult", "hult","run into hult"}
possible_answer_B_Q1 = {"b","run towards pier", "pier"}
possible_answer_C_Q1 = {"c","do nothing", "wait","approach","sit"}
possible_answer_D_Q1 = {"d","fight","throw","attack"}

possible_answer_yes = {"y","yes"}
possible_answer_no = {"n","no"}

possible_answer_choice_3A = {"a", "go upstair","check class room"}
possible_answer_choice_3B = {"b","go out","outside"}

possible_answer_choice_4A = {"a", "pub","pier 28"}
possible_answer_choice_4B = {"b","fisherman's wharf"}

final_choice_answer_A = {"a", "swim","jump","jump into the sea","sea"}
final_choice_answer_B = {"b", "ferry","sail"}

#game start by brief introduction of game, mgame aker and player 

def intro():
    
    global cohort_name #to have global variable of {cohort_name} throughout the scripts
    
    print("\nHello and welcome to Zombie's Apocalypse game. A game inspired by the Korean TV series 'Kingdom'")
    
    print("\nMy name is .... orch! my head is still spinning... well... the hang over just kick in again.....")
    
    print("\nMy name is Sian Yang, Hult MBA graduates in 2020! Nice to see you! Hope you enjoy the game!!!\n")
    
    print("""Welcome our cohort who will be experiencing Zombie Apocalyse in San Francisco!   

What's your name fellow cohort? 
""")
    # to cater for various possible name input, single word name, multiple words name and even empty space
    temp_cohort_name = input(prompt = "\nPlease input your name:\n")
    cohort_name_lst =temp_cohort_name.split() #converting multiple name in a list
    if len(cohort_name_lst) == 0: #case for empty space input
        
        print("\nCome on!!! Don't be shy, please tell us your name!!!\n")
        
        cohort_name = input(prompt = "Please input your name:\n")
        
        cohort_name = cohort_name.capitalize()
        
        print(f"\nWelcome {cohort_name}!!!!!!\n")
    
    elif len(cohort_name_lst) == 1: #case for single name input with capitalize function
        
        cohort_name = cohort_name_lst[0].capitalize()
        
        print(f"\nWelcome {cohort_name}!!!!!!\n")
    else: #case for capitalize multiple name input
        cohort_name = ""
        for name in cohort_name_lst: #for loop to add up capitalize individual name
        
            cohort_name += name.capitalize().strip()+" " 
            
        print(f"\nWelcome {cohort_name}!!!!!!\n")
    #considering all possible gender input for male or female, even prefer not to disclose or empty space which indicate "not to disclose"  
    gender = input(prompt = """Please input your gender(F/M/Leave empty if you prefer not to disclose):\n""")
    
    genderF = ["f","F","female","Female"]
    
    genderM = ["m","M","male","Male"]
    
    if gender in genderF:
        
        gender="she"
        gender2="her"
        
    elif gender in genderM:
        
        gender="he"
        gender2="him"
        
    elif gender == "":
        
        gender =gender2 = cohort_name
        
    else:
        
        print("Noted your intention, even you have key in an invalid input")
        gender =gender2 = cohort_name
    
    input("<Press any key to continue>\n")
    #Briefing of intro scenario, fetching {cohort_name} with input in gender/genders as pronouns
    print(f"""
    Imagined after a late night party in a Hult Alumni Event, {cohort_name} realised that {gender} were drunk,
    
    {gender} awaken the next morning in a park near Levi's plaza. With head spinning and fighting the urge to, 
    
    puke, {gender} struggling to stand up and wondering what had happened last night. The puzzling feeling fades 
    
    when {gender} hear a snarling sound emitting behind {gender2}. A man like creature with blood stains all  
    
    overall his body is running towards you. {gender} is going through 3 scenarios of choices to make a few  
    
    decisions in order to survive through this Zombie Apocalypse!
    
    """)
    
    input(prompt = "<press any key to continue>\n")
    #proceed to starting point "The park"
    scenario_1_park() 
    
def scenario_1_park():
    #briefing of park scenario
    print(f"{cohort_name}: welcome back to the scene!\n")
    
    print(f"""{cohort_name}, as you woke up on a bench in a park behind Levi's Plaza, a snarling sound has 
    
make you turn your head towards the sound direction, you saw a man-like-creature running towards you with 

blood stains all over his body. What is your reaction ???
""")
    input(prompt = "<press any key to continue>\n")
    # TWO chances are offerred in this games
    chances = 2
    
    while chances > 0: #while loop for 2 chances
        #Game first question
        print(f"""
{cohort_name}, what's your reaction? (You have {chances} chance(s) left.)

            A) Run into Hult campus to look for help.
            B) Run towards Pier direction.
            C) Do nothing or approach the man to ask him if he needs help.
            D) Pick up a stone or rubbish bin to fight against him.            
""")
        choice = input(prompt = f"{cohort_name}, please make a choice between A to D >>>\n")
        
        time.sleep(1) #time pause for 1 second
        
        choice =choice.lower() #converting input into lower case
        
        if choice in possible_answer_A_Q1: #choice of A, refer to the top for possible answer
            
            print(f"{cohort_name}, lucky you!! you decided to seek for help in Hult campus, let's see what happen next!!!\n")
            
            scenario_2_hult() #proceed to scenario 2, hult campus for help
            
            break 
           
        elif choice in possible_answer_B_Q1: #choice of B, refer to the top for possible answer
        
            print(f"{cohort_name}, smart! you are running towards an open area! seems it might be a better chance for staying alive!!!\n")
            
            scenario_3_pier()
            
            break
        
        elif choice in possible_answer_C_Q1: #choice of C, refer to the top for possible answer
            print(f"""Hey {cohort_name}, come on! Where is your Hult DNA? have some fighting spirit! Do nothing will end up bitten by the 
            
Zombie and becoming one of them. Sorry you're consider dead!!! you have {chances-1} chance(s) to try!!!

""")
            
            chances-=1 #losing one chance
             
        elif choice in possible_answer_D_Q1: #choice of D, refer to the top for possible answer
            
            print(f"""hey {cohort_name}, you have no fight against these Zombies as your action had attracted more zombies
            
coming and teaingr you into pieces! You're doomed!!!! You were definitely bitten by Zombies and becoming one of them!!

you have {chances-1} more chance(s) to try!!!
""")
            chances-=1 #losing one chance
        else: #prompt for invalid input
            print(f"""Hey {cohort_name}, you might have input an invalid answer for the game to proceed!!!
            
""")
            input(prompt = "<press any key to continue>\n")
                                           
    else:
        fail() #proceed to failing mode
      

def scenario_2_hult(): #function for scenario in Hult Campus
    
    print(f"""Hi {cohort_name}! Welcome back to Hult campus, thanks for trusting the security system of the school campus!!
    
When you entering the school campus you realised that there is nobody in the reception and you saw an axe on the desk,

will you picking it up?:           
""")
                  
    choice_2 = input(prompt = "Please make your choice(Yes/No): >>>\n") 
    
    choice_2 = choice_2.lower() #converting to lower case #converting choices to lower case to compare with anticipated answers
    
    hold_point = 1 #hold point to handle invalid input
    while hold_point > 0: #while input is incorrect, hold_point will be larger then 0
        if choice_2 in possible_answer_yes: #consider choice_2 possible answer "yes"with holding an axe

            print(f"""Hey {cohort_name}, you are holding an axe, what would you do next?
        
            A) Going upstairs to the Dean's office or other classroom to check out and seek for help.
            B) Go outside Hult campus.
""")
            choice_3 = input(prompt = "Please enter A or B:>>>\n")
        
            choice_3 = choice_3.lower() #converting to lower case
        
            if choice_3 in possible_answer_choice_3A: #consider choice_3A possible refer to the top of the scripts
                print(f"""Unfornatunately, there are more Zombie in Dean's office and class room, luckily you got 
            
an axe and you still manage to slaughter through and get out of Hult campus!!! You think of running towards the pier!
""")
                scenario_3_pier() #proceed to pier scenario
                
                hold_point-=1 #hold_point minus 1 for correct input
            elif choice_3 in possible_answer_choice_3B: #consider choice_3B possible refer to the top of the scripts

                print(f"""You make the right choice and heading to the pier as confined areas arent safe anymore!!!
""")
                scenario_3_pier() #proceed to pier scenario
                
                hold_point-=1 #hold_point minus 1 for correct input
            else:
                print(f"""Hey {cohort_name}, you might have keyed in an invalid input, please input A or B only!!!           
""")

                input(prompt = "<press any key to continue>\n")
                
                #hold_point remain as 1 for re-input
                
        elif choice_2 in possible_answer_no: #consider choice_2 possible answer "no "without holding an axe
        
            print(f"""hey {cohort_name}, you decided not to pick up the axe, what would you do next?
        
            A) Going upstairs to the Dean's office or other classroom to check out and seek for help.
            B) Go outside Hult campus.
""")
            choice_3 = input(prompt = "Please enter A or B:>>>\n")
        
            choice_3 = choice_3.lower() #convert to input to lower case
        
            if choice_3 in possible_answer_choice_3A: # comparing choice_3 with possible answers
                print(f"""Unfornatunately, there are more Zombie in Dean's office and class room, you have no 
            
Weapon to fight back, the next second you are surrounded by Zombie and were bitten to become one of them!!! 

You're a walking dead now!!!!!\n           
""")
                fail()
                hold_point-=1
                
            elif choice_3 in possible_answer_choice_3B:
                print(f"""You make the right choice and heading to the pier as confined areas aren't safe anymore!!!
""")
                scenario_3_pier() #procced to scenario pier
                
                hold_point-=1 #hold_point minus 1 for correct input
            else:
                print(f"""Hey {cohort_name}, you might have keyed in an invalid input, please input A or B only!!!\n
            
            """)
            
                input(prompt = "<press any key to continue>\n")
        
        else:
            print(f"""Hey {cohort_name}, you might have an invalid input, please input Yes or No only!!!\n
""")
            input(prompt = "<press any key to continue>\n")
            
            scenario_2_hult() #rediverting back to hult campus for invalid input
                  
def scenario_3_pier(): #function of stage 3 pier scenario
    
    print(f"""Hi {cohort_name}, are you still holding on or manage to pick up any weapon along your way???\n""")
    
    choice_2 = input(prompt = f"""Please make your choice(Yes/No): >>>\n""") 
    
    choice_2 = choice_2.lower() #convert input into lower case
    
    if choice_2 in possible_answer_yes: #handling answer yes
        axe = 1 #indicate picking up the axe
    elif choice_2 in possible_answer_no: #handling answer no
        axe =0 #indicate user didnt pick up the axe
    else: #handling invalid input
        print("Please input Yes or No .....")
        input(prompt = "<press any key to continue>\n")
        scenario_3_pier()
    answer = 1 #create while loop for handling error input
    while answer == 1:
        print(f"""Hi {cohort_name}! You had make it so far and fight your way out to the piers, however you notice that

there are somebody in the pub in pier areas. And also there are people running towards fisherman's wharf. Choices are:

            A) Go into a pub in pier area and seek for helps.
            B) Run towards fisherman's wharf.
""" )
    
        choice_4 = input(prompt="Please enter A or B:>>>\n")
        
        time.sleep(1) #pause for 1 second after user input
        
        choice_4 = choice_4.lower() #convert input into lower case
        
        if choice_4 in possible_answer_choice_4A: #comparing answer and possible answers
                print(f"""Unfornatunately, there are more zombies in the Pub (Confined space create higher infection rate),
        
however if you have any weapon, you still can make you way out!!!!! 
""")
                if axe == 1:
                    out_of_the_pier() #proceed out to pier
                    answer-=1 #answer minus 1 for correct input
                else:
                    print(f"""My dear {cohort_name}, since you have no weapon to defend yourself and get out of the Pub!!\n""")
                
                    fail() #divert to faling mode
                    
                    answer-=1 #answer minus 1 for correct input
    
        elif choice_4 in possible_answer_choice_4B: #comparing answer and possible answers
            print(f"""Dear {cohort_name}, I am great that you make it all the way to this stage, but you're doomed!!!!
        
It was realised that the infection center is in fisherman's wharf, there are highest number of zombies attacking

you !!! I felt sorry for you to have make this choice!!
""")
            fail() #divert to faling mode
            answer-=1 #answer minus 1 for correct input
        else:
            print(f"""Hey {cohort_name}, you might have input an invalid answer for the game to proceed!!!
            
Kindly try again with the valid respond, thanks!!!
""")
            answer = 1 #answer minus 1 for correct input
            input(prompt = "<press any key to continue>\n")
              
def out_of_the_pier(): #function for out of pier scenario
    
    chances = 2 #user will be given 2 chances
    
    while chances > 0: #while loop for no of try
        
        print(f"""Hey {cohort_name}!!!, I am impressed that you still surviving!!! Here's the final decision to made:
            
            A) Jump into the sea and swim towards Treasure Island.
            B) Hop in a ferry and set sail to Oakland.
            C) Type a single magic word to save you.
""")
        final_choice = input(prompt = f"Please enter a choice or a word (You have {chances} chance(s) left):>>>\n")
    
        final_choice = final_choice.lower() #conver input into lower case
    
        final_choice_split = final_choice.split() #handling "multiple word" key in, convert input into a list
    
        magic_word = {"dream"} #secret magic word
     
        if final_choice in final_choice_answer_A: #comparing answer and possible answers
            
            print(f"""Hi {cohort_name}! Congratulations!!! Well Done!!! You have make it to the end!!!!!! You had keyed in "{final_choice}" !!!
            
which means "A"!! You realised that Zombies are afraid of water............ :)
""")
            victory() #proceed to victory
                
        elif final_choice in final_choice_answer_B: #comparing answer and possible answers
            print(f"""Too bad {cohort_name}, You had keyed in "{final_choice}" which means "B", there is someone in the ferry infected 
            
with the virus and turn everyone onboard into Zombies........alas!!! You're doomed!!!
""") 
            chances-=1 #used up one chance for incorrect answer
                      
        elif final_choice in magic_word: #bingo magic word hit
            print(f"""Hey, {cohort_name}, You had keyed in magic word: "{final_choice}", don't worry, it is just a dream!!!!!! 
            
You are perfectly fine!!! Though it is still on distance learning, it is safe to go Hult campus when this pandemic is over!!!! 

Hope you are safe and healthy!!!

Now get back to your coding text-adventure game, you should be doing more debugging try to spot for errors.................!!!!
""")
            exit(0) #exit game
            
        elif len(final_choice_split) > 1: #handling multiple word input
            
            print(f"""Hey {cohort_name}, please key in one WORD only!!!""")
            
            input(prompt = "<press any key to continue>\n")
            
            chances -=1 #one chance used up for wrong input
            
            if chances == 0: #prompt for no more chance
                print(f"""Hey {cohort_name}, I am afraid you have no more chance!!!""")
                
        elif len(final_choice_split) == 1 and len(final_choice) > 1: #case for one word input with greater one charactor input
            
            print(f"""Hey {cohort_name}, wrong magic word!!!""")
            
            input(prompt = "<press any key to continue>\n")
            
            chances -= 1 #chance minus 1 for wrong input
            
            if chances == 0: #prompt for no more chance
                print(f"""Hey {cohort_name}, I am afraid you have no more chance!!!""")
            
        else:
            print(f"""Hey come on {cohort_name}, Wrong alphabet please try again to key in A , B or a SINGLE WORD!!!\n            
""")
            input(prompt = "<press any key to continue>\n")
            
            chances -= 1 #chance minus 1 for wrong input
            
            if chances == 0: #prompt for no more chance
                print(f"""Hey {cohort_name}, I am afraid you have no more chance!!!""")
    fail()
        
def fail(): #function defined for fail mode
    print("""Welcome to the club of 'Zombies'!!!!!, you are one of the walking dead!!!\n""")
    print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print(f"""     GAME OVER: I am so sorry {cohort_name}, You did not make it this round, please try again !!!!!!!!!""")
    print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    respond = input(prompt="Would you like to play again(Y/N)\n")
    respond = respond.lower()
    if respond in possible_answer_yes:
        intro()
    elif respond in possible_answer_no:
        print(f"""Thanks for playing !!!\n """)
        exit(0)
    else:
        print("Invalid input, please try again\n!!!")
        
        
def victory(): #function defined for victory mode
    print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    print(f"""        Horray! {cohort_name}, you make it! You are the sole survivor in San Francisco!!!""")
    print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
    exit(0)

intro() #proceed game start to intro()
